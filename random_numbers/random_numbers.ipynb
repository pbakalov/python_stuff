# %%
from random import random
from numpy import linspace, zeros
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
from utils import  power_law_cdf, power_law_pdf, power_law_rngen
    
    
# rns = []

x0 = 0.01
alpha = 1.05

xmax = 3.
nbins = 400
manual_hist = zeros(nbins, float)
bin_size = (xmax-x0)/nbins

for i in xrange(1000000):
    x = power_law_rngen(x0,alpha)
#     rns.append(x)
    if x<xmax:
        manual_hist[int((x-x0)/bin_size)] += 1
    
    
# plt.hist(rns, range = (x0,xmax),bins = nbins, density=True,log = True , stacked = True)
# print max(rns)
# print min(rns)

# %%
x_ = linspace(x0+bin_size/2,xmax-bin_size/2,nbins)
plt.plot(x_, manual_hist/manual_hist[0], '-o')

x_ = linspace(x0,xmax,10*nbins)
plt.plot(x_, power_law_pdf(x_, x0, alpha)/power_law_pdf(x0+bin_size/2, x0, alpha), '-')
plt.yscale('log')
plt.xscale('log')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from utils import power_law_with_init_plateau_cdf, \
                  power_law_with_init_plateau_pdf, \
                  power_law_with_init_plateau_rngen

alpha = 2.05
x0 = 0.5


xmax = 3.
xmin = 0.
nbins = 100
manual_hist = zeros(nbins, float)
bin_size = (xmax - xmin)/nbins

for i in xrange(5000000):
    x = power_law_with_init_plateau_rngen(x0,alpha)
    if x<xmax and x >= xmin:
        manual_hist[int((x-xmin)/bin_size)] += 1
        
x_ = linspace(xmin+bin_size/2,xmax-bin_size/2,nbins)
plt.plot(x_, manual_hist/manual_hist[0], '-o')

x_ = linspace(xmin,xmax, 10*nbins)

plt.plot(x_,
         power_law_with_init_plateau_pdf(x_,x0, alpha)/power_law_with_init_plateau_pdf([xmin+bin_size/2.],x0, alpha))
# plt.plot(x_, power_law_with_init_plateau_cdf(x_,x0, alpha))
# Out:
# <img src="data:image/png;base64,..." width="640">
